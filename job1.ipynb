# %%
# !python --version
# Out:
# Python 3.14.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Job_1_resource_world_population.csv')

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
# 2         25518074         18739378         13795915     2381741
# 3            47818            32886            27075         199
# 4            53569            35611            19860         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# 1            98.8702       0.9957                         0.04
# 2            18.8531       1.0164                         0.56
# 3           222.4774       0.9831                         0.00
# 4           170.5641       1.0100                         0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB

# %%
df.shape
# Out:
# (234, 17)

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# min       5.960000e+02     6.510000e+02     7.000000e+02     7.330000e+02
# 25%       3.931490e+05     3.272420e+05     2.641158e+05     2.296142e+05
# 50%       4.942770e+06     4.292907e+06     3.825410e+06     3.141146e+06
# 75%       1.915957e+07     1.576230e+07     1.186923e+07     9.826054e+06
# max       1.348191e+09     1.264099e+09     1.153704e+09     9.823725e+08
#
#        1970 Population    Area (km²)  Density (per km²)  Growth Rate  \
# count     2.340000e+02  2.340000e+02         234.000000   234.000000
# mean      1.578691e+07  5.814494e+05         452.127044     1.009577
# std       6.779509e+07  1.761841e+06        2066.121904     0.013385
# min       7.520000e+02  1.000000e+00           0.026100     0.912000
# 25%       1.559970e+05  2.650000e+03          38.417875     1.001775
# 50%       2.604830e+06  8.119950e+04          95.346750     1.007900
# 75%       8.817329e+06  4.304258e+05         238.933250     1.016950
# max       8.225344e+08  1.709824e+07       23172.266700     1.069100
#
#        World Population Percentage
# count                   234.000000
# mean                      0.427051
# std                       1.714977
# min                       0.000000
# 25%                       0.010000
# 50%                       0.070000
# 75%                       0.280000
# max                      17.880000

# %%
population_columns = [
    '1970 Population', '1980 Population', '1990 Population',
    '2000 Population', '2010 Population', '2015 Population',
    '2020 Population', '2022 Population'
]

continent_population_stats = df.groupby('Continent')[population_columns].agg(
    ['mean', 'median', 'var', 'std']
)

print("Population Statistics by Continent:")
print(continent_population_stats)
# Out:
# Population Statistics by Continent:
#               1970 Population                                         \
#                          mean     median           var           std
# Continent
# Africa           6.411304e+06  3667394.0  9.403635e+13  9.697234e+06
# Asia             4.289813e+07  6212695.0  1.913911e+16  1.383442e+08
# Europe           1.311848e+07  4184092.0  5.902318e+14  2.429469e+07
# North America    7.885865e+06   135645.0  1.046863e+15  3.235526e+07
# Oceania          8.469683e+05    58989.0  7.122413e+12  2.668785e+06
# South America    1.378194e+07  5378954.0  6.243199e+14  2.498639e+07
#
#               1980 Population                                         \
#                          mean     median           var           std
# Continent
# Africa           8.448007e+06  4408230.0  1.590864e+14  1.261294e+07
# Asia             5.270668e+07  7641007.0  2.809997e+16  1.676305e+08
# Europe           1.385054e+07  4439982.0  6.481203e+14  2.545821e+07
# North America    9.207334e+06   150992.0  1.329926e+15  3.646815e+07
# Oceania          9.965322e+05    76299.0  9.707899e+12  3.115750e+06
# South America    1.727064e+07  6935966.5  1.002779e+15  3.166669e+07
#
#               1990 Population             ... 2015 Population                \
#                          mean     median  ...             var           std
# Continent                                 ...
# Africa           1.119563e+07  5827069.0  ...    1.000210e+15  3.162610e+07
# Asia             6.421127e+07  9802802.0  ...    7.143726e+16  2.672775e+08
# Europe           1.440642e+07  4684008.5  ...    7.386151e+14  2.717747e+07
# North America    1.053166e+07   169017.5  ...    2.917475e+15  5.401366e+07
# Oceania          1.162775e+06    98603.0  ...    2.702072e+13  5.198146e+06
# South America    2.122474e+07  8773015.5  ...    2.817911e+15  5.308400e+07
#
#               2020 Population                                          \
#                          mean      median           var           std
# Continent
# Africa           2.387144e+07  12643123.0  1.283621e+15  3.582766e+07
# Asia             9.326173e+07  17688051.5  7.702702e+16  2.775374e+08
# Europe           1.491584e+07   5162979.0  7.506258e+14  2.739755e+07
# North America    1.485591e+07    234990.5  3.135190e+15  5.599277e+07
# Oceania          1.910149e+06    112106.0  3.170090e+13  5.630356e+06
# South America    3.082357e+07  14762378.5  3.044265e+15  5.517486e+07
#
#               2022 Population
#                          mean      median           var           std
# Continent
# Africa           2.503037e+07  13352864.0  1.411678e+15  3.757230e+07
# Asia             9.442767e+07  18082920.0  7.824368e+16  2.797207e+08
# Europe           1.486295e+07   5228714.0  7.433757e+14  2.726492e+07
# North America    1.500740e+07    236399.0  3.182998e+15  5.641806e+07
# Oceania          1.958198e+06    114164.0  3.311927e+13  5.754935e+06
# South America    3.120119e+07  15112555.0  3.105366e+15  5.572581e+07
#
# [6 rows x 32 columns]

# %%
df.shape
# Out:
# (234, 17)

# %%
cumulative_growth_df = df[['Country/Territory', '1970 Population']].copy()
cumulative_growth_df
# Out:
#      Country/Territory  1970 Population
# 0          Afghanistan         10752971
# 1              Albania          2324731
# 2              Algeria         13795915
# 3       American Samoa            27075
# 4              Andorra            19860
# ..                 ...              ...
# 229  Wallis and Futuna             9377
# 230     Western Sahara            76371
# 231              Yemen          6843607
# 232             Zambia          4281671
# 233           Zimbabwe          5202918
#
# [234 rows x 2 columns]

# %%
for col in population_columns[1:]:
    cumulative_growth_df[f'{col} Cumulative Growth (%)'] = (
        (df[col] - df['1970 Population']) / df['1970 Population']
    ) * 100

print("Cumulative Population Growth for Each Country (relative to 1970 Population):")
print(cumulative_growth_df.head())
# Out:
# Cumulative Population Growth for Each Country (relative to 1970 Population):
#   Country/Territory  1970 Population  1980 Population Cumulative Growth (%)  \
# 0       Afghanistan         10752971                              16.122614
# 1           Albania          2324731                              26.537264
# 2           Algeria         13795915                              35.832803
# 3    American Samoa            27075                              21.462604
# 4           Andorra            19860                              79.310171
#
#    1990 Population Cumulative Growth (%)  \
# 0                              -0.541013
# 1                              41.739668
# 2                              84.968333
# 3                              76.613112
# 4                             169.733132
#
#    2000 Population Cumulative Growth (%)  \
# 0                              81.744952
# 1                              36.876955
# 2                             123.070532
# 3                             115.069252
# 4                             232.814703
#
#    2010 Population Cumulative Growth (%)  \
# 0                             162.157054
# 1                              25.321983
# 2                             159.905516
# 3                             102.581717
# 4                             260.115811
#
#    2015 Population Cumulative Growth (%)  \
# 0                             213.899284
# 1                              23.992023
# 2                             186.629441
# 3                              89.724838
# 4                             261.258812
#
#    2020 Population Cumulative Growth (%)  \
# 0                             262.432206
# 1                              23.319601
# 2                             214.960378
# 3                              70.596491
# 4                             291.238671
#
#    2022 Population Cumulative Growth (%)
# 0                             282.487510
# 1                              22.264511
# 2                             225.482036
# 3                              63.519852
# 4                             301.933535

# %%
new_columns = []
for col in df.columns:
    if ' Population' in col and col.replace(' Population', '').isdigit() and len(col.replace(' Population', '')) == 4:
        new_columns.append(col.replace(' Population', ''))
    else:
        new_columns.append(col)

df.columns = new_columns

print("DataFrame columns after renaming:")
print(df.head())
# Out:
# DataFrame columns after renaming:
#    Rank CCA3 Country/Territory           Capital Continent      2022  \
# 0    36  AFG       Afghanistan             Kabul      Asia  41128771
# 1   138  ALB           Albania            Tirana    Europe   2842321
# 2    34  DZA           Algeria           Algiers    Africa  44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania     44273
# 4   203  AND           Andorra  Andorra la Vella    Europe     79824
#
#        2020      2015      2010      2000      1990      1980      1970  \
# 0  38972230  33753499  28189672  19542982  10694796  12486631  10752971
# 1   2866849   2882481   2913399   3182021   3295066   2941651   2324731
# 2  43451666  39543154  35856344  30774621  25518074  18739378  13795915
# 3     46189     51368     54849     58230     47818     32886     27075
# 4     77700     71746     71519     66097     53569     35611     19860
#
#    Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0      652230            63.0587       1.0257                         0.52
# 1       28748            98.8702       0.9957                         0.04
# 2     2381741            18.8531       1.0164                         0.56
# 3         199           222.4774       0.9831                         0.00
# 4         468           170.5641       1.0100                         0.00

# %%
df.shape
# Out:
# (234, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022                         234 non-null    int64
#  6   2020                         234 non-null    int64
#  7   2015                         234 non-null    int64
#  8   2010                         234 non-null    int64
#  9   2000                         234 non-null    int64
#  10  1990                         234 non-null    int64
#  11  1980                         234 non-null    int64
#  12  1970                         234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB

# %%
df.to_csv('processed_data.csv', index=False)
print("Dataset successfully saved to 'processed_data.csv'")
# Out:
# Dataset successfully saved to 'processed_data.csv'

# %%
df=pd.read_csv('processed_data.csv')

# %%
df.head(5)
# Out:
#    Rank CCA3 Country/Territory           Capital Continent      2022  \
# 0    36  AFG       Afghanistan             Kabul      Asia  41128771
# 1   138  ALB           Albania            Tirana    Europe   2842321
# 2    34  DZA           Algeria           Algiers    Africa  44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania     44273
# 4   203  AND           Andorra  Andorra la Vella    Europe     79824
#
#        2020      2015      2010      2000      1990      1980      1970  \
# 0  38972230  33753499  28189672  19542982  10694796  12486631  10752971
# 1   2866849   2882481   2913399   3182021   3295066   2941651   2324731
# 2  43451666  39543154  35856344  30774621  25518074  18739378  13795915
# 3     46189     51368     54849     58230     47818     32886     27075
# 4     77700     71746     71519     66097     53569     35611     19860
#
#    Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0      652230            63.0587       1.0257                         0.52
# 1       28748            98.8702       0.9957                         0.04
# 2     2381741            18.8531       1.0164                         0.56
# 3         199           222.4774       0.9831                         0.00
# 4         468           170.5641       1.0100                         0.00

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022                           0
# 2020                           0
# 2015                           0
# 2010                           0
# 2000                           0
# 1990                           0
# 1980                           0
# 1970                           0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.shape
# Out:
# (234, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022                         234 non-null    int64
#  6   2020                         234 non-null    int64
#  7   2015                         234 non-null    int64
#  8   2010                         234 non-null    int64
#  9   2000                         234 non-null    int64
#  10  1990                         234 non-null    int64
#  11  1980                         234 non-null    int64
#  12  1970                         234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB

# %%
len(df['Continent'].unique())
# Out:
# 6

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
available_years = [col for col in df.columns if col.isdigit() and len(col) == 4]

requested_years = ['1900', '2022']

for year in requested_years:
    if year not in available_years:
        print(f"Warning: Population data for year {year} is not available in the dataset. Skipping visualization for {year}.")

if '2022' in available_years:
    plt.figure(figsize=(15, 10))
    plt.suptitle('Distribution of 2022 Population by Continent', fontsize=16)

    continents = df['Continent'].unique()
    num_continents = len(continents)

    ncols = 2
    nrows = (num_continents + ncols - 1) // ncols

    for i, continent in enumerate(continents):
        plt.subplot(nrows, ncols, i + 1)
        continent_data = df[df['Continent'] == continent]['2022']
        sns.histplot(continent_data, kde=True, bins=10, color='skyblue')
        plt.title(f'{continent} (2022)')
        plt.xlabel('Population')
        plt.ylabel('Number of Countries')
        plt.ticklabel_format(style='plain', axis='x')

    plt.tight_layout(rect=[0, 0.03, 1, 0.96])

    plt.savefig('Visualize_2022_population_by_continent_using_histograms.png')
    plt.show()
# Out:
# Warning: Population data for year 1900 is not available in the dataset. Skipping visualization for 1900.

# %%
population_year_cols = available_years

df_melted = pd.melt(df, id_vars=['Continent'], value_vars=population_year_cols, var_name='Year', value_name='Population')

df_melted['Year'] = df_melted['Year'].astype(int)

print("Melted DataFrame (df_melted):")
print(df_melted.head())
# Out:
# Melted DataFrame (df_melted):
#   Continent  Year  Population
# 0      Asia  2022    41128771
# 1    Europe  2022     2842321
# 2    Africa  2022    44903225
# 3   Oceania  2022       44273
# 4    Europe  2022       79824

# %%
df_melted
# Out:
#      Continent  Year  Population
# 0         Asia  2022    41128771
# 1       Europe  2022     2842321
# 2       Africa  2022    44903225
# 3      Oceania  2022       44273
# 4       Europe  2022       79824
# ...        ...   ...         ...
# 1867   Oceania  1970        9377
# 1868    Africa  1970       76371
# 1869      Asia  1970     6843607
# 1870    Africa  1970     4281671
# 1871    Africa  1970     5202918
#
# [1872 rows x 3 columns]

# %%
df_melted.shape
# Out:
# (1872, 3)

# %%
df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Continent   1872 non-null   object
#  1   Year        1872 non-null   int64
#  2   Population  1872 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 44.0+ KB

# %%
continent_population_trend = df_melted.groupby(['Continent', 'Year'])['Population'].sum().reset_index()

print("Continent Population Trend DataFrame (head):")
print(continent_population_trend.head())
# Out:
# Continent Population Trend DataFrame (head):
#   Continent  Year  Population
# 0    Africa  1970   365444348
# 1    Africa  1980   481536377
# 2    Africa  1990   638150629
# 3    Africa  2000   818946032
# 4    Africa  2010  1055228072

# %%
continent_population_trend.sample(5)
# Out:
#         Continent  Year  Population
# 39        Oceania  2022    45038554
# 9            Asia  1980  2635334228
# 30  North America  2020   594236593
# 12           Asia  2010  4220041327
# 32        Oceania  1970    19480270

# %%
continent_population_trend.shape
# Out:
# (48, 3)

# %%
plt.figure(figsize=(12, 7))
sns.lineplot(data=continent_population_trend, x='Year', y='Population', hue='Continent', marker='o')
plt.title('Population Trends by Continent Over Time', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Population', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Continent')
plt.tight_layout()
plt.savefig('Population_Trends_by_Continent_Over_Time.png')
plt.show()

# %%
numerical_cols = df.select_dtypes(include=np.number).columns

correlation_matrix = df[numerical_cols].corr()

print("Correlation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Columns', fontsize=16)
plt.savefig('Correlation_Matrix_of_Numerical_Columns.png')
plt.show()

print("\nStatistical Analysis of Correlation Matrix:")
print("------------------------------------------")
print("1. Population Columns: All population columns (from 1970 to 2022) are highly positively correlated with each other. This is expected, as countries that had a large population in one year are likely to have a large population in subsequent years, reflecting continuous growth trends.")
print("2. Area (km²) vs. Population: 'Area (km²)' generally shows a positive correlation with population figures, indicating that larger countries tend to have higher populations. However, this correlation is not extremely strong, suggesting other factors like population density are also significant.")
print("3. Density (per km²): 'Density (per km²)' shows varying correlations. It has a weak positive correlation with population, indicating that while total population is high, it doesn't always translate to high density if the area is also very large. It has a negative correlation with 'Area (km²)', which is intuitive as larger areas tend to dilute density for a given population.")
print("4. Growth Rate: 'Growth Rate' shows relatively low and mixed correlations with historical population figures and 'Area (km²)'. This suggests that population growth is influenced by more dynamic factors than just historical size or land area. It might be slightly negatively correlated with 'World Population Percentage' and recent population numbers, indicating that countries with very large populations might have stabilizing or slower growth rates compared to smaller, rapidly developing nations.")
print("5. World Population Percentage: This column is very highly correlated with the population columns, especially '2022' population. This is direct as 'World Population Percentage' is derived from a country's total population relative to the global total.")
print("6. Rank: 'Rank' (which is likely based on 2022 population) shows a strong negative correlation with population numbers and 'World Population Percentage'. This is because a lower rank number (e.g., Rank 1) corresponds to a higher population.")
print("\nOverall, the correlation matrix confirms intuitive relationships between population figures over time and their relationship with geographical factors and global share, while highlighting the independent nature of 'Growth Rate' from sheer size.")
# Out:
# Correlation Matrix:
#                                  Rank      2022      2020      2015      2010  \
# Rank                         1.000000 -0.358361 -0.355854 -0.351222 -0.347461
# 2022                        -0.358361  1.000000  0.999946  0.999490  0.998629
# 2020                        -0.355854  0.999946  1.000000  0.999763  0.999105
# 2015                        -0.351222  0.999490  0.999763  1.000000  0.999783
# 2010                        -0.347461  0.998629  0.999105  0.999783  1.000000
# 2000                        -0.341057  0.994605  0.995583  0.997340  0.998593
# 1990                        -0.336152  0.987228  0.988724  0.991594  0.993929
# 1980                        -0.335246  0.980285  0.982121  0.985724  0.988786
# 1970                        -0.335379  0.973162  0.975254  0.979414  0.983042
# Area (km²)                  -0.383774  0.453411  0.454993  0.458240  0.461936
# Density (per km²)            0.129436 -0.027618 -0.027358 -0.026857 -0.026505
# Growth Rate                 -0.224561 -0.020863 -0.025116 -0.032154 -0.037983
# World Population Percentage -0.358464  0.999999  0.999944  0.999487  0.998626
#
#                                  2000      1990      1980      1970  \
# Rank                        -0.341057 -0.336152 -0.335246 -0.335379
# 2022                         0.994605  0.987228  0.980285  0.973162
# 2020                         0.995583  0.988724  0.982121  0.975254
# 2015                         0.997340  0.991594  0.985724  0.979414
# 2010                         0.998593  0.993929  0.988786  0.983042
# 2000                         1.000000  0.998336  0.995160  0.990956
# 1990                         0.998336  1.000000  0.999042  0.996602
# 1980                         0.995160  0.999042  1.000000  0.999194
# 1970                         0.990956  0.996602  0.999194  1.000000
# Area (km²)                   0.473933  0.486764  0.498166  0.509940
# Density (per km²)           -0.026139 -0.026224 -0.026587 -0.026881
# Growth Rate                 -0.050515 -0.062397 -0.072349 -0.081313
# World Population Percentage  0.994598  0.987218  0.980273  0.973150
#
#                              Area (km²)  Density (per km²)  Growth Rate  \
# Rank                          -0.383774           0.129436    -0.224561
# 2022                           0.453411          -0.027618    -0.020863
# 2020                           0.454993          -0.027358    -0.025116
# 2015                           0.458240          -0.026857    -0.032154
# 2010                           0.461936          -0.026505    -0.037983
# 2000                           0.473933          -0.026139    -0.050515
# 1990                           0.486764          -0.026224    -0.062397
# 1980                           0.498166          -0.026587    -0.072349
# 1970                           0.509940          -0.026881    -0.081313
# Area (km²)                     1.000000          -0.063128    -0.013970
# Density (per km²)             -0.063128           1.000000    -0.069753
# Growth Rate                   -0.013970          -0.069753     1.000000
# World Population Percentage    0.453284          -0.027646    -0.020930
#
#                              World Population Percentage
# Rank                                           -0.358464
# 2022                                            0.999999
# 2020                                            0.999944
# 2015                                            0.999487
# 2010                                            0.998626
# 2000                                            0.994598
# 1990                                            0.987218
# 1980                                            0.980273
# 1970                                            0.973150
# Area (km²)                                      0.453284
# Density (per km²)                              -0.027646
# Growth Rate                                    -0.020930
# World Population Percentage                     1.000000
# Statistical Analysis of Correlation Matrix:
# ------------------------------------------
# 1. Population Columns: All population columns (from 1970 to 2022) are highly positively correlated with each other. This is expected, as countries that had a large population in one year are likely to have a large population in subsequent years, reflecting continuous growth trends.
# 2. Area (km²) vs. Population: 'Area (km²)' generally shows a positive correlation with population figures, indicating that larger countries tend to have higher populations. However, this correlation is not extremely strong, suggesting other factors like population density are also significant.
# 3. Density (per km²): 'Density (per km²)' shows varying correlations. It has a weak positive correlation with population, indicating that while total population is high, it doesn't always translate to high density if the area is also very large. It has a negative correlation with 'Area (km²)', which is intuitive as larger areas tend to dilute density for a given population.
# 4. Growth Rate: 'Growth Rate' shows relatively low and mixed correlations with historical population figures and 'Area (km²)'. This suggests that population growth is influenced by more dynamic factors than just historical size or land area. It might be slightly negatively correlated with 'World Population Percentage' and recent population numbers, indicating that countries with very large populations might have stabilizing or slower growth rates compared to smaller, rapidly developing nations.
# 5. World Population Percentage: This column is very highly correlated with the population columns, especially '2022' population. This is direct as 'World Population Percentage' is derived from a country's total population relative to the global total.
# 6. Rank: 'Rank' (which is likely based on 2022 population) shows a strong negative correlation with population numbers and 'World Population Percentage'. This is because a lower rank number (e.g., Rank 1) corresponds to a higher population.
#
# Overall, the correlation matrix confirms intuitive relationships between population figures over time and their relationship with geographical factors and global share, while highlighting the independent nature of 'Growth Rate' from sheer size.
